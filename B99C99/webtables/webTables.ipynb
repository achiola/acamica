# %%
# es necesario antes de hacer el import de pandas instalar esta libreria **conda install lxml**

import pandas as pd
url = r'https://www.ign.gob.ar/NuestrasActividades/Geografia/DatosArgentina/VolcanesActivos'
tables = pd.read_html(url) # Returns list of all tables on page
volcanes = tables[0] # Select table of interest

volcanes
# Out:
#                       Denominación          Provincia  Lat.(S) Long. (O)  \
# 0                       Co. TUZGLE              Jujuy  24° 03’   66° 29'
# 1                       Vn. ARACAR              Salta  24° 18'   67° 47'
# 2                      Vn. SOCOMPA              Salta  24° 24'   68° 15'
# 3                 Co. LLULLAILLACO              Salta  24° 43'   68° 32'
# 4                 SALAR DE ARIZARO              Salta  24° 44'   67° 54'
# 5                     Co. ESCORIAL              Salta  25° 05'   68° 22'
# 6           Vn. AZUFRE o LASTARRÍA  Salta / Catamarca  25° 10'   68° 30'
# 7                CORDÓN DEL AZUFRE          Catamarca  25° 20'   68° 31'
# 8                  Co. BAYO GORBEA          Catamarca  25° 25'   68° 34'
# 9                  Vn. ANTOFAGASTA          Catamarca  26° 07'   67° 24'
# 10               Co. SIERRA NEVADA          Catamarca  26° 30'   68° 35'
# 11                   Co. EL CÓNDOR          Catamarca  26° 38'   68° 22'
# ...
